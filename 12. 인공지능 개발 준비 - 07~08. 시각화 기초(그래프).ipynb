# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

#그래프 창이 새로운 창으로 뜰 수 있음

# %matplotlib inline

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data = np.random.randn(50).cumsum()
data
# Out:
# array([ 0.52812819, -1.28597208, -0.41339346,  0.96369117,  1.34141408,
#         2.70858071,  4.13235816,  4.20189996,  3.11397564,  3.22035102,
#         4.17269776,  3.3337095 ,  2.7317275 ,  1.51296167,  4.91988811,
#         5.70085938,  5.65521593,  6.31795669,  5.00006357,  3.82684187,
#         4.11820314,  5.08386279,  5.559192  ,  5.10602729,  5.20886896,
#         3.80214704,  3.11135618,  4.15467478,  3.15379367,  5.32477777,
#         6.78080814,  7.21103221,  7.2720143 ,  7.49180874,  7.83056477,
#         6.88215624,  8.10594905,  9.44834006,  7.9200486 ,  7.05618123,
#         7.56124009,  7.15230753,  8.5338691 , 10.27535579,  8.30552875,
#         8.08129359,  9.27516012,  9.9513978 ,  9.74913561,  9.51254115])

# %%
plt.plot(data)
plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1, 2, 1) # 하나의 이미지 속에 여러 개의 그래프를 그리겠다 : subplot
plt.subplot(1, 2, 2) # (행의 갯수, 열의 갯수, 순서)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
hist_data = np.random.randn(100)
scat_data = np.arange(30)

# %%
#순서에 따라 데이터를 도식화시킨다.

plt.subplot(2, 2, 1)
plt.plot(data)

plt.subplot(2, 2, 2)
plt.hist(hist_data, bins = 20)

plt.subplot(2, 2, 3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30)) #x축 데이터, y축 데이터 순서

plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점), --(긴 점선)

# %%
plt.plot(data, 'y')
plt.show()

# %%
plt.plot(data, 'k--') #string으로 색상 + 모양의 순서로 작성한다.
plt.show()

# %%
plt.plot(data, 'r^')
plt.show()

# %%
plt.plot(data, 'bv')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.plot(data, 'k+')
plt.show()

# %%
plt.figure(figsize = (10, 5)) #사이즈 단위는 인치
plt.plot(data, 'k+')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize = (10, 5))

plt.subplot(2, 2, 1)
plt.plot(data)

plt.subplot(2, 2, 2)
plt.hist(hist_data, bins = 20)

plt.subplot(2, 2, 3)
plt.scatter(scat_data, np.arange(30) + 3 * np.random.randn(30)) #x축 데이터, y축 데이터 순서

plt.show()

# %% [markdown]
# - 비율 조절

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %% [markdown]
# ---
# ## 이름 달기

# %% [markdown]
# ---
# ## 종합

# %% [markdown]
# ---
# ## 그래프 저장하기
